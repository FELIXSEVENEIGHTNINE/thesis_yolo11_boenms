# %%
# Install ultralytics and dependencies
# !pip install -q ultralytics matplotlib scikit-learn seaborn pandas opencv-python-headless PyYAML tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.8 MB/s eta 0:00:00

# %%
# !rm -rf /content/e-waste-dataset

# %%
# Mount Google Drive and extract dataset
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import zipfile, os, shutil
from pathlib import Path

GDRIVE_ZIP_PATH = "/content/drive/MyDrive/e-waste-dataset-4.zip"
EXTRACT_TO = Path("/content/e-waste-dataset")

if not Path(GDRIVE_ZIP_PATH).exists():
    raise FileNotFoundError(f"Zip not found at {GDRIVE_ZIP_PATH}")

if EXTRACT_TO.exists():
    shutil.rmtree(EXTRACT_TO)
with zipfile.ZipFile(GDRIVE_ZIP_PATH, 'r') as zf:
    zf.extractall(EXTRACT_TO)
print("Dataset extracted to", EXTRACT_TO)
# Out:
# Mounted at /content/drive
# Dataset extracted to /content/e-waste-dataset

# %%
# Create data.yaml with absolute paths
import yaml

dataset_root = EXTRACT_TO
train_images = str(dataset_root / "train" / "images")
val_images   = str(dataset_root / "valid" / "images")
test_images  = str(dataset_root / "test" / "images")

class_names = ['battery', 'electronic-waste', 'keyboard', 'laptop',
               'mobile phone', 'monitor', 'mouse']

data_yaml_path = Path("/content/data_for_training.yaml")
data_for_training = {
    "train": train_images,
    "val": val_images,
    "test": test_images,
    "nc": len(class_names),
    "names": class_names
}
with open(data_yaml_path, "w") as f:
    yaml.dump(data_for_training, f, sort_keys=False)
print(open(data_yaml_path).read())
# Out:
# train: /content/e-waste-dataset/train/images
# val: /content/e-waste-dataset/valid/images
# test: /content/e-waste-dataset/test/images
# nc: 7
# names:
# - battery
# - electronic-waste
# - keyboard
# - laptop
# - mobile phone
# - monitor
# - mouse

# %%
# 4) Train YOLOv11 with BOE-NMS Model
from ultralytics import YOLO
import torch

EPOCHS = 30
IMGSZ = 256
BATCH = 16
MODEL_NAME = "e_waste_yolov11_boe-nms"

# Load standard YOLOv11
model = YOLO("yolo11n.pt")

# Patch BOE-NMS
def box_iou(box1, box2):
    # IoU helper for BOE-NMS
    area1 = (box1[:, 2] - box1[:, 0]) * (box1[:, 3] - box1[:, 1])
    area2 = (box2[:, 2] - box2[:, 0]) * (box2[:, 3] - box2[:, 1])

    inter_x1 = torch.max(box1[:, None, 0], box2[:, 0])
    inter_y1 = torch.max(box1[:, None, 1], box2[:, 1])
    inter_x2 = torch.min(box1[:, None, 2], box2[:, 2])
    inter_y2 = torch.min(box1[:, None, 3], box2[:, 3])

    inter = (inter_x2 - inter_x1).clamp(0) * (inter_y2 - inter_y1).clamp(0)
    return inter / (area1[:, None] + area2 - inter)

def boe_nms(boxes, scores, iou_thres=0.45, conf_thres=0.25):
    # Balanced Overlap-Eliminated NMS
    keep = []
    idxs = scores.argsort(descending=True)

    while idxs.numel() > 0:
        i = idxs[0]
        keep.append(i.item())
        if idxs.numel() == 1:
            break

        ious = box_iou(boxes[i].unsqueeze(0), boxes[idxs[1:]])[0]

        penalty = (1 - ious)
        scores[idxs[1:]] = scores[idxs[1:]] * penalty

        idxs = idxs[1:][scores[idxs[1:]] > conf_thres]

    return torch.tensor(keep, device=boxes.device)

# Ultralytics NMS
from ultralytics.utils import ops
def custom_nms(pred, conf_thres=0.25, iou_thres=0.45, classes=None, agnostic=False, max_det=300, nm=0):
    if pred.shape[0] == 0:
        return pred
    boxes, scores = pred[:, :4], pred[:, 4]
    keep = boe_nms(boxes, scores, iou_thres=iou_thres, conf_thres=conf_thres)
    return pred[keep]
ops.non_max_suppression = custom_nms
print("BOE-NMS successfully patched")
# Out:
# BOE-NMS successfully patched

# %%
# Train YOLOv11 with BOE-NMS Model
model.train(data=str(data_yaml_path), epochs=EPOCHS, imgsz=IMGSZ,
            batch=BATCH, name=MODEL_NAME)

trained_weights = f"runs/detect/{MODEL_NAME}/weights/best.pt"
print("Training complete. Best weights at:", trained_weights)
# Out:
# Ultralytics 8.3.219 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data_for_training.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=256, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=e_waste_yolov11_boe-nms2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/e_waste_yolov11_boe-nms2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    432037  ultralytics.nn.modules.head.Detect           [7, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,591,205 parameters, 2,591,189 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 355.8±167.2 MB/s, size: 7.4 KB)
# train: Scanning /content/e-waste-dataset/train/labels... 5433 images, 2 backgrounds, 256 corrupt: 100% ━━━━━━━━━━━━ 5433/5433 2.5Kit/s 2.2s
# train: /content/e-waste-dataset/train/images/e-waste-3220-_jpg.rf.ec27b43dcf19620fec701e764e011aa2.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3221-_jpg.rf.6c8cdd13e489953a296da1851d01adef.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3278-_jpg.rf.af1dd771caffae9f621e0b45ed93b66f.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3281-_jpg.rf.4200878ef467a130d608db3c11bc2057.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3283-_jpg.rf.de1f4a8a51a91238e2649d57477101d7.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3284-_jpg.rf.32dc30596113132a808ce723ff74c2de.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3285-_jpg.rf.0301f71c99b52a4a223217433f4a4043.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3286-_jpg.rf.1ec2f5a28a41670b441f8ab62b2ffda2.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3287-_jpg.rf.65843b51b7c73e9690b1f9fea9655787.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3289-_jpg.rf.174eb16eba173f9d9eb9cbf959a5f9ae.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3292-_jpg.rf.77be47a70dad761f7855a0e4aeb8a8a2.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3293-_jpg.rf.e916120c327d0f20988e77fdd839f9e4.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3294-_jpg.rf.6f3289b941d6e93718798c9bfe567abb.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-3296-_jpg.rf.de7106b263760910b2c38de04e1602cd.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-389-_jpg.rf.5a41a9106efdca4db6a7fb57f8ceb03b.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4772-_jpg.rf.55798174b6bf470ad7c66b07f3d859df.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4794-_jpg.rf.32fa04b6b1559f868feac7ece52ae714.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4797-_jpg.rf.3fb1a6cbb05a2de5cd344975b103fbd2.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4798-_jpg.rf.dd0ec1682872e2b76c1a08b7cb21c4b3.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4799-_jpg.rf.2b97145b8fc50e15cd9aa0b39c94f1b4.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4800-_jpg.rf.e5be977b03ce1fdb46e107f4142b4611.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4801-_jpg.rf.2f666055e5aa2ba65b9e64669078ba5c.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4803-_jpg.rf.0c3aaba60f9b746358da16fa99405a04.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4805-_jpg.rf.931facc4e7ba0e660085c6bd785a6574.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4806-_jpg.rf.8d11f5ddc93f6b97ee74166041cb6e51.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4808-_jpg.rf.7f5ffd98c411b3010c7f8b176a5e9a25.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-4809-_jpg.rf.2b52709ff682d6a7c1ce4568a9b028b6.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 7. Possible class labels are 0-6
# train: /content/e-waste-dataset/train/images/e-waste-
0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30     0.863G     0.9895     0.9735      1.214         21        256: 100% ━━━━━━━━━━━━ 324/324 7.4it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 8.3it/s 1.7s
#                    all        445        445      0.409      0.403      0.368      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30     0.879G     0.9716     0.9358      1.203         19        256: 100% ━━━━━━━━━━━━ 324/324 7.4it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 5.7it/s 2.5s
#                    all        445        445      0.422      0.387      0.354      0.217
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30     0.895G     0.9226     0.6877      1.182          9        256: 100% ━━━━━━━━━━━━ 324/324 7.4it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 6.0it/s 2.3s
#                    all        445        445      0.352      0.298      0.289      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30     0.908G     0.8854     0.6116      1.161          9        256: 100% ━━━━━━━━━━━━ 324/324 7.6it/s 42.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 8.4it/s 1.7s
#                    all        445        445      0.332       0.45      0.323      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30     0.924G     0.8791     0.6022      1.163          9        256: 100% ━━━━━━━━━━━━ 324/324 7.7it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 8.3it/s 1.7s
#                    all        445        445      0.404      0.427      0.366      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30     0.938G      0.862     0.5594      1.152          9        256: 100% ━━━━━━━━━━━━ 324/324 7.7it/s 42.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 8.3it/s 1.7s
#                    all        445        445      0.394      0.475      0.382      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30     0.953G     0.8382     0.5355      1.143          9        256: 100% ━━━━━━━━━━━━ 324/324 7.7it/s 41.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 7.0it/s 2.0s
#                    all        445        445      0.446      0.467       0.38      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30     0.967G     0.8379     0.5155      1.137          9        256: 100% ━━━━━━━━━━━━ 324/324 7.6it/s 42.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 7.9it/s 1.8s
#                    all        445        445      0.459       0.42      0.346      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30     0.982G     0.8296     0.5106      1.134          9        256: 100% ━━━━━━━━━━━━ 324/324 7.4it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 8.4it/s 1.7s
#                    all        445        445       0.38      0.415       0.34      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30     0.998G     0.8191      0.485      1.124          9        256: 100% ━━━━━━━━━━━━ 324/324 7.7it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 8.4it/s 1.7s
#                    all        445        445      0.395      0.391      0.326      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      1.01G     0.8069     0.4723      1.123          9        256: 100% ━━━━━━━━━━━━ 324/324 7.7it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 8.6it/s 1.6s
#                    all        445        445       0.36      0.389      0.308      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      1.03G     0.7972     0.4625      1.112          9        256: 100% ━━━━━━━━━━━━ 324/324 7.6it/s 42.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 6.0it/s 2.3s
#                    all        445        445      0.362      0.405      0.325      0.214
#
# 30 epochs completed in 0.381 hours.
# Optimizer stripped from /content/runs/detect/e_waste_yolov11_boe-nms2/weights/last.pt, 5.4MB
# Optimizer stripped from /content/runs/detect/e_waste_yolov11_boe-nms2/weights/best.pt, 5.4MB
#
# Validating /content/runs/detect/e_waste_yolov11_boe-nms2/weights/best.pt...
# Ultralytics 8.3.219 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 5.6it/s 2.5s
#                    all        445        445      0.455      0.493      0.433      0.288
#                battery         47         47      0.114       0.66      0.136     0.0447
#       electronic-waste        100        100      0.273       0.11      0.234      0.153
#               keyboard         54         54      0.582      0.537      0.597      0.453
#                 laptop         67         67      0.565      0.448      0.556      0.423
#           mobile phone         43         43        0.3      0.744      0.483      0.373
#                monitor         58         58      0.863       0.19       0.49      0.332
#                  mouse         76         76      0.486      0.763      0.531      0.233
# Speed: 0.0ms preprocess, 1.0ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to /content/runs/detect/e_waste_yolov11_boe-nms2
# Training complete. Best weights at: runs/detect/e_waste_yolov11_boe-nms/weights/best.pt

# %%
# !rm -rf /content/runs/detect/e_waste_yolov11_boe-nms

# %%
# Run evaluation
import numpy as np, cv2, time, json
from sklearn.metrics import confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# Load trained model for inference
infer_model = YOLO(trained_weights)

# Helper: Load YOLO labels
def load_yolo_labels(label_path, img_w, img_h):
    objs = []
    if not os.path.exists(label_path):
        return objs
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls = int(float(parts[0]))
            x_c, y_c, w, h = [float(x) for x in parts[1:5]]
            xmin = (x_c - w/2) * img_w
            ymin = (y_c - h/2) * img_h
            xmax = (x_c + w/2) * img_w
            ymax = (y_c + h/2) * img_h
            objs.append({'class': cls, 'bbox':[xmin, ymin, xmax, ymax]})
    return objs

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    inter = max(0, xB-xA) * max(0, yB-yA)
    areaA = max(0, boxA[2]-boxA[0]) * max(0, boxA[3]-boxA[1])
    areaB = max(0, boxB[2]-boxB[0]) * max(0, boxB[3]-boxB[1])
    if areaA + areaB - inter == 0:
        return 0
    return inter / (areaA + areaB - inter)

# %%
# Prepare test images
test_images_dir = Path(test_images)
img_extensions = [".jpg", ".jpeg", ".png", ".bmp"]
test_files = [p for p in sorted(test_images_dir.iterdir()) if p.suffix.lower() in img_extensions]

num_classes = len(class_names)
TP, FP, FN = [0]*num_classes, [0]*num_classes, [0]*num_classes
confusion_pairs, all_gt, all_pred = [], [], []
inf_times = []

IOU_THRESHOLD = 0.5
CONF_THRESHOLD = 0.25

for img_path in tqdm(test_files, desc="Evaluating"):
    img = cv2.imread(str(img_path))
    if img is None: continue
    h, w = img.shape[:2]
    label_file = Path(str(img_path).replace("/images/", "/labels/")).with_suffix('.txt')
    gt_objs = load_yolo_labels(str(label_file), w, h)

    # Filter out ground truth objects with invalid class labels
    gt_objs = [obj for obj in gt_objs if 0 <= obj['class'] < num_classes]

    t0 = time.time()
    results = infer_model.predict(source=str(img_path), conf=CONF_THRESHOLD, iou=0.45, imgsz=IMGSZ, verbose=False)
    t1 = time.time()
    inf_times.append(t1 - t0)

    preds = []
    res = results[0]
    if res.boxes is not None:
        xyxy = res.boxes.xyxy.cpu().numpy()
        cls_arr = res.boxes.cls.cpu().numpy().astype(int)
        for b, c in zip(xyxy, cls_arr):
            # Filter out predictions with invalid class labels
            if 0 <= c < num_classes:
                preds.append({'class': c, 'bbox':[b[0], b[1], b[2], b[3]]})


    # IoU matching
    matched_gt, matched_pred = set(), set()
    iou_mat = np.zeros((len(gt_objs), len(preds)))
    for i,g in enumerate(gt_objs):
        for j,p in enumerate(preds):
            iou_mat[i,j] = iou(g['bbox'], p['bbox'])

    while iou_mat.size > 0 and np.max(iou_mat) >= IOU_THRESHOLD:
        gi,pj = np.unravel_index(np.argmax(iou_mat), iou_mat.shape)
        gt_cls, pred_cls = gt_objs[gi]['class'], preds[pj]['class']
        if gt_cls == pred_cls:
            TP[gt_cls]+=1
        else:
            FP[pred_cls]+=1; FN[gt_cls]+=1
        confusion_pairs.append((gt_cls, pred_cls))
        all_gt.append(gt_cls); all_pred.append(pred_cls)
        matched_gt.add(gi); matched_pred.add(pj)
        iou_mat[gi,:] = -1; iou_mat[:,pj] = -1

    # Unmatched predictions → false positives
    for j in range(len(preds)):
        if j not in matched_pred:
            FP[preds[j]['class']]+=1
            all_gt.append(-1)
            all_pred.append(preds[j]['class'])

    # Unmatched ground truths → false negatives
    for i in range(len(gt_objs)):
        if i not in matched_gt:
            FN[gt_objs[i]['class']]+=1
            all_gt.append(gt_objs[i]['class'])
            all_pred.append(-1)
# Out:
# Evaluating: 100%|██████████| 445/445 [00:04<00:00, 93.21it/s]

# %%
# Evaluation Metrics
precision, recall, f1 = [],[],[]
for c in range(num_classes):
    tp,fp,fn = TP[c],FP[c],FN[c]
    p = tp/(tp+fp) if tp+fp>0 else 0
    r = tp/(tp+fn) if tp+fn>0 else 0
    f = (2*p*r)/(p+r) if (p+r)>0 else 0
    precision.append(p); recall.append(r); f1.append(f)

accuracy = sum(TP) / (sum(TP)+sum(FP)+sum(FN)) if (sum(TP)+sum(FP)+sum(FN))>0 else 0
avg_latency = np.mean(inf_times) if inf_times else float('nan')

# %%
# Build confusion matrix
cm = confusion_matrix(all_gt, all_pred, labels=list(range(num_classes)) + [-1])

# Display Evaluation Summary
print("==== Evaluation Summary (YOLOv11 + BOE-NMS) ====")
print(f"Avg latency (s/img): {avg_latency:.4f}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {np.mean(precision):.4f}")
print(f"Recall: {np.mean(recall):.4f}")
print(f"F1-Score:{np.mean(f1):.4f}")

# Plot confusion matrix
cm_display = cm[:-1,:-1]
plt.figure(figsize=(10,8))
sns.heatmap(cm_display, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted"); plt.ylabel("Ground Truth")
plt.title("Confusion Matrix (YOLOv11 + BOE-NMS, IoU>=0.5)")
plt.tight_layout()
plt.savefig("/content/confusion_matrix_yolov11_boe-nms.png", dpi=200)
plt.show()
# Out:
# ==== Evaluation Summary (YOLOv11 + BOE-NMS) ====
# Avg latency (s/img): 0.0099
# Accuracy: 0.1420
# Precision: 0.3356
# Recall: 0.2946
# F1-Score:0.2585

# %%
# !zip -r /content/YOLO11_BOENMS.zip /content/runs

from google.colab import files
files.download("/content/YOLO11_BOENMS.zip")
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/.ipynb_checkpoints/ (stored 0%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/ (stored 0%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/val_batch2_pred.jpg (deflated 22%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/val_batch1_pred.jpg (deflated 24%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/train_batch2.jpg (deflated 4%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/BoxR_curve.png (deflated 8%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/train_batch6482.jpg (deflated 11%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/val_batch0_labels.jpg (deflated 23%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/train_batch1.jpg (deflated 7%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/BoxPR_curve.png (deflated 11%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/results.png (deflated 6%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/val_batch1_labels.jpg (deflated 25%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/val_batch0_pred.jpg (deflated 23%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/args.yaml (deflated 53%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/train_batch6481.jpg (deflated 12%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/results.csv (deflated 60%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/labels.jpg (deflated 25%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/confusion_matrix_normalized.png (deflated 16%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/BoxP_curve.png (deflated 5%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/confusion_matrix.png (deflated 21%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/val_batch2_labels.jpg (deflated 23%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/BoxF1_curve.png (deflated 8%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/train_batch6480.jpg (deflated 10%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/weights/ (stored 0%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/weights/last.pt (deflated 10%)
#   adding: content/runs/detect/e_waste_yolov11_boe-nms/weights/best.pt (deflated 10%)
